# %%
import pandas as pd
import re

# Load your DataFrame
df = pd.read_csv('../data/modern_Data.csv')

# %%
df.head()
# Out:
#                            Channel Title       Channel Username    ID  \
# 0  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4573
# 1  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4572
# 2  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4571
# 3  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 4  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4569
#
#                                              Message  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 4                                                NaN
#
#                         Date                             Media Path  \
# 0  2024-09-26 11:50:31+00:00                                    NaN
# 1  2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4572.jpg
# 2  2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4571.jpg
# 3  2024-09-26 11:50:31+00:00                                    NaN
# 4  2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4569.jpg
#
#        Sender ID  Views  Forwards  Reply To Message ID  \
# 0 -1001649695480   4288         2                  NaN
# 1 -1001649695480   4280         2                  NaN
# 2 -1001649695480   4279         2                  NaN
# 3 -1001649695480   4280         2                  NaN
# 4 -1001649695480   5912         0                  NaN
#
#                                            Reactions  Reply Count
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3  [<telethon.tl.types.ReactionCount object at 0x...            0
# 4                                                NaN            0

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 2543

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (1499, 12)

# %%
df
# Out:
#                               Channel Title       Channel Username    ID  \
# 0     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4573
# 1     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4572
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4571
# 3     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 4     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4569
# ...                                     ...                    ...   ...
# 4037  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     8
# 4038  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     6
# 4039  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     5
# 4040  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     4
# 4041  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     1
#
#                                                 Message  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 4                                                   NaN
# ...                                                 ...
# 4037  እጅግ በጣም ኳሊቲ የቡና መፍጫ\nየማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ  ያ...
# 4038  ኳሊቲ የቡና ስኒ ከነማስቀመጫው፣ከነመስቀያው\nበ950ብር \nአድራሻ ጉርድ...
# 4039  ተንጠልጣይ የሻይ፣የቡና እና የወተት ኮምፕሌት\nበ600ብር ብቻ\nአድራሻ ...
# 4040                                                NaN
# 4041                                                NaN
#
#                            Date                             Media Path  \
# 0     2024-09-26 11:50:31+00:00                                    NaN
# 1     2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4572.jpg
# 2     2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4571.jpg
# 3     2024-09-26 11:50:31+00:00                                    NaN
# 4     2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4569.jpg
# ...                         ...                                    ...
# 4037  2022-02-18 17:42:21+00:00     photos\@modernshoppingcenter_8.jpg
# 4038  2022-02-18 17:40:19+00:00     photos\@modernshoppingcenter_6.jpg
# 4039  2022-02-18 17:37:43+00:00     photos\@modernshoppingcenter_5.jpg
# 4040  2022-02-18 17:37:43+00:00     photos\@modernshoppingcenter_4.jpg
# 4041  2022-02-18 17:25:37+00:00                                    NaN
#
#           Sender ID  Views  Forwards  Reply To Message ID  \
# 0    -1001649695480   4288         2                  NaN
# 1    -1001649695480   4280         2                  NaN
# 2    -1001649695480   4279         2                  NaN
# 3    -1001649695480   4280         2                  NaN
# 4    -1001649695480   5912         0                  NaN
# ...             ...    ...       ...                  ...
# 4037 -1001649695480   6852         6                  NaN
# 4038 -1001649695480   6969         2                  NaN
# 4039 -1001649695480   6845         8                  NaN
# 4040 -1001649695480   6719         8                  NaN
# 4041 -1001649695480      0         0                  NaN
#
#                                               Reactions  Reply Count
# 0                                                   NaN            0
# 1                                                   NaN            0
# 2                                                   NaN            0
# 3     [<telethon.tl.types.ReactionCount object at 0x...            0
# 4                                                   NaN            0
# ...                                                 ...          ...
# 4037  [<telethon.tl.types.ReactionCount object at 0x...            0
# 4038  [<telethon.tl.types.ReactionCount object at 0x...            0
# 4039                                                NaN            0
# 4040  [<telethon.tl.types.ReactionCount object at 0x...            0
# 4041                                                NaN            0
#
# [4042 rows x 12 columns]

# %%
message_df=df['Message']
message_df
# Out:
# 3       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 5       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 9       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 14      ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 17      ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
#                               ...
# 4034    የተለያየ ማራኪ ቅርጽ ያላችው የቡና ሲኒዎች\nበ600ብር ብቻ\nአድራሻ ጉ...
# 4036    ለጨው፣ለስኳር ማቅረቢያ\nከንፁህ ሴራሚክ የተሰራ\nበ400ብር ብቻ።\nአድ...
# 4037    እጅግ በጣም ኳሊቲ የቡና መፍጫ\nየማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ  ያ...
# 4038    ኳሊቲ የቡና ስኒ ከነማስቀመጫው፣ከነመስቀያው\nበ950ብር \nአድራሻ ጉርድ...
# 4039    ተንጠልጣይ የሻይ፣የቡና እና የወተት ኮምፕሌት\nበ600ብር ብቻ\nአድራሻ ...
# Name: Message, Length: 1499, dtype: object

# %%
message_df.head()
# Out:
# 3     ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 5     ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 9     ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 14    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 17    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# Name: Message, dtype: object

# %% [markdown]
# # Preprocessing: Removing Emojies, blank lines, and unwanted texts

# %%
import pandas as pd

# Load the dataset
def load_dataset(file_path):
    df = pd.read_csv(file_path)
    return df

# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Function to remove blank lines from the dataset
def remove_blank_lines(df, column_name):
    # Remove rows where the message is either NaN or only contains whitespace
    df[column_name] = df[column_name].replace(r'^\s*$', pd.NA, regex=True)
    df = df.dropna(subset=[column_name])
    return df

# Function to remove unwanted texts from messages
def remove_unwanted_texts(df, column_name, unwanted_texts):
    # Iterate through each row and remove unwanted texts and double quotes
    for index, row in df.iterrows():
        message = row[column_name]
        if isinstance(message, str):
            # Remove unwanted texts
            for unwanted_text in unwanted_texts:
                if unwanted_text in message:
                    message = message.replace(unwanted_text, "")
            # Remove double quotes
            message = message.replace('"', "")
            df.at[index, column_name] = message.strip()
    return df

# Save the cleaned dataset to a new file
def save_cleaned_dataset(df, output_file):
    df.to_csv(output_file, index=False)
    print(f"Cleaned dataset saved to {output_file}")

# Main function
def main(input_file, output_file, column_name, unwanted_texts):
    df = load_dataset(input_file)

    # Handle Missing Values
    df = df.dropna(subset=['Message'])

    # Apply the function to the 'Message' column
    df['Message'] = df['Message'].apply(remove_emojis)

    # Remove blank lines (or rows with empty messages)
    df = remove_blank_lines(df, column_name)

    # Clean the messages by removing unwanted texts and double quotes
    cleaned_df = remove_unwanted_texts(df, column_name, unwanted_texts)

    # Save the cleaned dataset to a new CSV file
    save_cleaned_dataset(cleaned_df, output_file)

if __name__ == "__main__":
    # Specify the input file and output file paths
    input_file = "../data/modern_Data.csv"
    output_file = "../data/cleaned_dataset.csv"

    # Define the column containing the messages
    column_name = "Message"

    # List of unwanted texts to remove from the messages
    unwanted_texts = [
        "ቴሌግራምt.me/modernshoppingcenter",
        '"በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን"',
        "t.me/modernshopping1",
        "t.me/modernshopping2",
        "በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን።",
        "0956415152",
        "0924743736",
        "0974978584",
        '"በሞደርን እቃወዏች ሂወትዎን',
        ' ሞደርናይዝ ያድርጉ"',
        'የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን',
        'ተጀመረ ተጀመረ ተጀመረ',
        'ልዩ እዉነተኛ የበዓል ቅናሽ',
        'ከነሐሴ 29 እስከ መስከረም 7 ድረስ የሚቆይ እዉነተኛ ቅናሽ አድርገናል።',
        'ለክፍለሀገር ደንበኞቻችን ባሉበት ሐገር በመናሐሪያ እንልካለን።',
    ]

    # Run the main function
    main(input_file, output_file, column_name, unwanted_texts)
# Out:
# Cleaned dataset saved to ../data/cleaned_dataset.csv

# %% [markdown]
# # Labelling the dataset: Tokenizing and Labelling

# %%
import pandas as pd

# Load the dataset
def load_dataset(file_path):
    df = pd.read_csv(file_path)
    return df

# Function to tokenize the Amharic text (a simple split based on space)
def tokenize_message(message):
    # Convert to string to avoid issues with float/NaN values
    if isinstance(message, str):
        return message.split()
    else:
        return []

# Manual annotation function
def annotate_message(tokens):
    labeled_tokens = []
    print("\nStart labeling each token:")
    for token in tokens:
        print(f"Token: {token}")
        label = input("Enter label (B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O): ")
        labeled_tokens.append((token, label))
    return labeled_tokens

# Save the labeled data in CoNLL format
def save_to_conll(labeled_data, output_file):
    with open(output_file, 'w', encoding='utf-8') as f:
        for message in labeled_data:
            for token, label in message:
                f.write(f"{token} {label}\n")
            f.write("\n")  # Blank line to separate messages

# Main function to annotate dataset
def main(file_path, output_file, start_row, num_rows):
    df = load_dataset(file_path)

    labeled_data = []

    # Subset the dataframe based on the start_row and num_rows
    df_subset = df.iloc[start_row : start_row + num_rows]

    # Assuming the dataset has a 'Message' column
    for index, row in df_subset.iterrows():
        message = row['Message']

        # Tokenize the message (handle non-string cases)
        tokens = tokenize_message(message)

        if tokens:  # Skip messages that couldn't be tokenized (empty or non-string)
            print(f"\nMessage {index + 1}: {message}")

            # Annotate tokens
            labeled_tokens = annotate_message(tokens)

            # Append labeled tokens
            labeled_data.append(labeled_tokens)

    # Save the annotated data in CoNLL format
    save_to_conll(labeled_data, output_file)
    print(f"\nAnnotated data saved to {output_file}")

if __name__ == "__main__":
    # Provide the path to the dataset and the output file
    dataset_path = "../data/cleaned_dataset.csv"
    output_file = "../data/labeled_data.txt"

    # Specify the starting row and number of rows to process
    start_row = int(input("Enter the starting row: "))
    num_rows = int(input("Enter the number of rows to label: "))

    main(dataset_path, output_file, start_row, num_rows)
# Out:
# Message 15: sokani 7in1 sandwich maker
#  በተለይ ለህፃናት ቁርስ ለማዘጋጀት ተመራጭ
#  ሰባት የተለያዩ ነገሮችን መስራት የሚችል ተቀያያሪ ፕሌት ያለው
#  በሁለቱም በኩል የሚግል
#  ሙቀቱን በራሱ የሚቆጣጠር
#  750watt የሆነ
#  ለአጠቃቀም ቀላል
#
#           በ
#     6800
#
#
#
#
#
#
#
#
#
#
#
#
# አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# አድራሻ=ቁጥር 1 = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ሆሊሲቲ ሴንተር ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#            ቁጥር 2 = ጀሞ መስታወትፋብሪካ ፊትለፊት ራሐ ሞል ግራዉንድ ፍሎር ከደረጃዉ ጎን።
#
#
#                    ሞደርናይዝ ያድርጉ
#
# Start labeling each token:
# Token: sokani
# Token: 7in1
# Token: sandwich
# Token: maker
# Token: በተለይ
# Token: ለህፃናት
# Token: ቁርስ
# Token: ለማዘጋጀት
# Token: ተመራጭ
# Token: ሰባት
# Token: የተለያዩ
# Token: ነገሮችን
# Token: መስራት
# Token: የሚችል
# Token: ተቀያያሪ
# Token: ፕሌት
# Token: ያለው
# Token: በሁለቱም
# Token: በኩል
# Token: የሚግል
# Token: ሙቀቱን
# Token: በራሱ
# Token: የሚቆጣጠር
# Token: 750watt
# Token: የሆነ
# Token: ለአጠቃቀም
# Token: ቀላል
# Token: በ
# Token: 6800
# Token: አዲስ
# Token: አበባ
# Token: ዉስጥ
# Token: ከ100ብር
# Token: እስከ
# Token: 200ብር
# Token: ብቻ
# Token: በማስከፈል
# Token: ያሉበት
# Token: ድረስ
# Token: በፈጣን
# Token: ሞተረኞቻችን
# Token: እንልክልዏታለን።
# Token: አድራሻ=ቁጥር
# Token: 1
# Token: =
# Token: ጉርድሾላ
# Token: ከሴንቸሪ
# Token: ሞል
# Token: ትንሽ
# Token: ዝቅ
# Token: እንዳሉ
# Token: ሆሊሲቲ
# Token: ሴንተር
# Token: ላይ
# Token: እንደገቡ
# Token: ፊትለፊት
# Token: ከሊፍቱ
# Token: በግራ
# Token: በኩል
# Token: ሚዛን
# Token: ላይ
# Token: M06
# Token: ቁጥር
# Token: 2
# Token: =
# Token: ጀሞ
# Token: መስታወትፋብሪካ
# Token: ፊትለፊት
# Token: ራሐ
# Token: ሞል
# Token: ግራዉንድ
# Token: ፍሎር
# Token: ከደረጃዉ
# Token: ጎን።
# Token: ሞደርናይዝ
# Token: ያድርጉ
#
# Message 16: Shake 'n Take Fruit Juice Blender
#  ቀጥታ በሶኬት ገመድ ተሰክቶ የሚሰራ
#  የፍራፍሬ እና ሼክ ጁሶችን ለማዘጋጀት ተመራጥ
#  ለቤትና ለቢሮ አገልግሎት የሚሆን
#  ለልጆችዎ ፈጣን ጁስ ለማዘጋጀት
#  500ml የሚይዙ 2 ጆጎች
# ያሉት
#  በተጨማሪም ክዳን ስላለው በቀላሉ ይዘውት መንቀሳቀስ የሚያስችል
#  ለአጠቃቀም ቀላል
#
#               በ
#          1800
#
#
#
#
#
#
#
#
#
#
#
#
# አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# አድራሻ=ቁጥር 1 = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ሆሊሲቲ ሴንተር ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#            ቁጥር 2 = ጀሞ መስታወትፋብሪካ ፊትለፊት ራሐ ሞል ግራዉንድ ፍሎር ከደረጃዉ ጎን።
#
#
#                    ሞደርናይዝ ያድርጉ
#
# Start labeling each token:
# Token: Shake
# Token: 'n
# Token: Take
# Token: Fruit
# Token: Juice
# Token: Blender
# Token: ቀጥታ
# Token: በሶኬት
# Token: ገመድ
# Token: ተሰክቶ
# Token: የሚሰራ
# Token: የፍራፍሬ
# Token: እና
# Token: ሼክ
# Token: ጁሶችን
# Token: ለማዘጋጀት
# Token: ተመራጥ
# Token: ለቤትና
# Token: ለቢሮ
# Token: አገልግሎት
# Token: የሚሆን
# Token: ለልጆችዎ
# Token: ፈጣን
# Token: ጁስ
# Token: ለማዘጋጀት
# Token: 500ml
# Token: የሚይዙ
# Token: 2
# Token: ጆጎች
# Token: ያሉት
# Token: በተጨማሪም
# Token: ክዳን
# Token: ስላለው
# Token: በቀላሉ
# Token: ይዘውት
# Token: መንቀሳቀስ
# Token: የሚያስችል
# Token: ለአጠቃቀም
# Token: ቀላል
# Token: በ
# Token: 1800
# Token: አዲስ
# Token: አበባ
# Token: ዉስጥ
# Token: ከ100ብር
# Token: እስከ
# Token: 200ብር
# Token: ብቻ
# Token: በማስከፈል
# Token: ያሉበት
# Token: ድረስ
# Token: በፈጣን
# Token: ሞተረኞቻችን
# Token: እንልክልዏታለን።
# Token: አድራሻ=ቁጥር
# Token: 1
# Token: =
# Token: ጉርድሾላ
# Token: ከሴንቸሪ
# Token: ሞል
# Token: ትንሽ
# Token: ዝቅ
# Token: እንዳሉ
# Token: ሆሊሲቲ
# Token: ሴንተር
# Token: ላይ
# Token: እንደገቡ
# Token: ፊትለፊት
# Token: ከሊፍቱ
# Token: በግራ
# Token: በኩል
# Token: ሚዛን
# Token: ላይ
# Token: M06
# Token: ቁጥር
# Token: 2
# Token: =
# Token: ጀሞ
# Token: መስታወትፋብሪካ
# Token: ፊትለፊት
# Token: ራሐ
# Token: ሞል
# Token: ግራዉንድ
# Token: ፍሎር
# Token: ከደረጃዉ
# Token: ጎን።
# Token: ሞደርናይዝ
# Token: ያድርጉ
#
# Message 17: ሽንኩርት ሲልጡ ጥፍርዏና ጣትዏ እየቆሸሸ ተቸግረዋል??? ይሄዉ መፍትሄዉ
#
#  የተለያዩ አትክልቶችን ለመላጥ
#  በርበሬ ለመቀንጠስ፣ዝንጅብል ለመላጥ ፣ወዘተ ተመራጭ
#  አንዱ እሽግ ለ5 ቱም ጣት ማስገቢያ ያለዉ
#  ለአጠቃቀም በጣም ቀላል
#
#             በ
#      300ብር
#
#
#
#
#
#
#
#
#
#
#
#
# አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# አድራሻ=ቁጥር 1 = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ሆሊሲቲ ሴንተር ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#            ቁጥር 2 = ጀሞ መስታወትፋብሪካ ፊትለፊት ራሐ ሞል ግራዉንድ ፍሎር ከደረጃዉ ጎን።
#
#
#                    ሞደርናይዝ ያድርጉ
#
# Start labeling each token:
# Token: ሽንኩርት
# Token: ሲልጡ
# Token: ጥፍርዏና
# Token: ጣትዏ
# Token: እየቆሸሸ
# Token: ተቸግረዋል???
# Token: ይሄዉ
# Token: መፍትሄዉ
# Token: የተለያዩ
# Token: አትክልቶችን
# Token: ለመላጥ
# Token: በርበሬ
# Token: ለመቀንጠስ፣ዝንጅብል
# Token: ለመላጥ
# Token: ፣ወዘተ
# Token: ተመራጭ
# Token: አንዱ
# Token: እሽግ
# Token: ለ5
# Token: ቱም
# Token: ጣት
# Token: ማስገቢያ
# Token: ያለዉ
# Token: ለአጠቃቀም
# Token: በጣም
# Token: ቀላል
# Token: በ
# Token: 300ብር
# Token: አዲስ
# Token: አበባ
# Token: ዉስጥ
# Token: ከ100ብር
# Token: እስከ
# Token: 200ብር
# Token: ብቻ
# Token: በማስከፈል
# Token: ያሉበት
# Token: ድረስ
# Token: በፈጣን
# Token: ሞተረኞቻችን
# Token: እንልክልዏታለን።
# Token: አድራሻ=ቁጥር
# Token: 1
# Token: =
# Token: ጉርድሾላ
# Token: ከሴንቸሪ
# Token: ሞል
# Token: ትንሽ
# Token: ዝቅ
# Token: እንዳሉ
# Token: ሆሊሲቲ
# Token: ሴንተር
# Token: ላይ
# Token: እንደገቡ
# Token: ፊትለፊት
# Token: ከሊፍቱ
# Token: በግራ
# Token: በኩል
# Token: ሚዛን
# Token: ላይ
# Token: M06
# Token: ቁጥር
# Token: 2
# Token: =
# Token: ጀሞ
# Token: መስታወትፋብሪካ
# Token: ፊትለፊት
# Token: ራሐ
# Token: ሞል
# Token: ግራዉንድ
# Token: ፍሎር
# Token: ከደረጃዉ
# Token: ጎን።
# Token: ሞደርናይዝ
# Token: ያድርጉ
#
# Message 18: እጅግ በጣም ኳሊቲ በራድ
#  እሳት ላይ መጣድ የሚችል
#  3 ሊትር የመያዝ አቅም ያለው
#  እስቴለስ እስቲል ስለሆነ የማይዝግ
#  እጀታው የማይግል
#  የራሱ ማሥተንፈሻ ቀዳዳ
# ያለው
#  በፕረስ (በመጫን) የሚከፈት
#  ለአጠቃቀም ቀላል
#
#               በ
#          2600
#
#
#
#
#
#
#
#
#
#
#
#
# አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# አድራሻ=ቁጥር 1 = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ሆሊሲቲ ሴንተር ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#            ቁጥር 2 = ጀሞ መስታወትፋብሪካ ፊትለፊት ራሐ ሞል ግራዉንድ ፍሎር ከደረጃዉ ጎን።
#
#
#                    ሞደርናይዝ ያድርጉ
#
# Start labeling each token:
# Token: እጅግ
# Token: በጣም
# Token: ኳሊቲ
